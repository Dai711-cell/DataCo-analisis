# %% [markdown]
# # DataCo Supply Chain Analytics
#
# Notebook principal del proyecto. El objetivo inicial es entender los datos recibidos antes de limpiar, transformar o modelar.
#
# Regla de arranque: los datasets raw permanecen intactos. Cualquier salida derivada debe guardarse fuera de los archivos originales.

# %% [markdown]
# ## 1. Objetivo del proyecto
#
# Pendiente de concretar con una pregunta principal de negocio o analisis.
#
# Posibles direcciones:
#
# - analizar rendimiento operativo de supply chain;
# - estudiar retrasos, entregas y servicio;
# - analizar ventas, margen, clientes, productos y regiones;
# - explorar patrones de acceso web a partir de logs tokenizados;
# - preparar un baseline predictivo solo despues de revisar granularidad y leakage.

# %% [markdown]
# ## 2. Inventario de fuentes
#
# Completar despues de revisar `DescriptionDataCoSupplyChain.csv`.
#
# | Fuente | Formato | Granularidad | Claves | Fechas | Notas de calidad |
# |---|---|---|---|---|---|
# | `DataCoSupplyChainDataset.csv` | CSV | Pendiente | Pendiente | Pendiente | Pendiente |
# | `DescriptionDataCoSupplyChain.csv` | CSV | Diccionario | Pendiente | No aplica | Pendiente |
# | `tokenized_access_logs.csv` | CSV | Pendiente | Pendiente | Pendiente | Pendiente |

# %% [markdown]
# ## 3. Preguntas iniciales
#
# - Que representa cada fila del dataset principal?
# - Que columnas son identificadores, fechas, categorias y metricas numericas?
# - Que variable podria ser objetivo si se plantea un modelo?
# - Que columnas podrian causar leakage?
# - Como se relacionan los logs tokenizados con el dataset de supply chain, si es que se relacionan?

# %% [markdown]
# ## 4. Setup
#
# La primera celda de codigo deberia limitarse a imports, rutas relativas y configuracion de visualizacion. No escribir salidas sobre los datasets originales.

# %% [markdown]
# ## 5. Exploracion inicial
#
# Pendiente. Empezar con lectura ligera de metadatos, columnas, tipos, rangos de fechas y conteos basicos.

# %% [markdown]
# ## 6. Decisiones y dudas
#
# Registrar aqui decisiones de limpieza, joins, granularidad, metricas y posibles riesgos.
